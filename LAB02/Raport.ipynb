# %% [markdown]
# # Raport Laboratori: Markdown
#
# ## 1. Titulli
# Laboratori 2: Dokumentimi me Markdown
#
# ## 2. Qëllimi
# Mësimi i strukturimit të dokumenteve teknike.
#
# ## 3. Bazat
# Markdown përdoret për formatim të thjeshtë teksti.
#
# ## 4. Mjetet
# JupyterLab dhe Conda.
#
# ## 5. Analiza
# Këtu mund të vendosni shembuj kodi: `print('Hello')`
